# %% [markdown]
# # Model Training workbook
# This is an workbook for student to train their model using train dataset

# %% [markdown]
# ## Library imports

# %%
import Common.Utilities as util
import Common.Preprocessing as preprocessing
import Common.Visualization as visualization
import Common.Modeling as modeling

# %%
trainDataset = util.getTrainDataset()
display(trainDataset)
# Out:
#          WellName      TestUsage        Date  OilRate (STB/D)  \
# 0        WELL-136     Allocation  2013-01-01      2673.952618
# 1        WELL-143     Allocation  2013-01-03     10832.359750
# 2     WELL-107ST2     Allocation  2013-01-03      8452.715356
# 3        WELL-140     Allocation  2013-01-04      2861.703543
# 4        WELL-122     Allocation  2013-01-05      4406.443130
# ...           ...            ...         ...              ...
# 1083     WELL-114  Informational  2017-12-23      7810.029554
# 1084     WELL-136     Allocation  2017-12-26      1091.203321
# 1085     WELL-103  Informational  2017-12-27      8327.844997
# 1086     WELL-101  Informational  2017-12-29      6083.819551
# 1087     WELL-146  Informational  2017-12-30       413.396346
#
#       WaterRate (STB/D)  GasRate (MSCF/D)  GasLiftRate (MSCF/D)  \
# 0           8695.560470          2.545241              3.354898
# 1           5496.560666         27.898769              3.167271
# 2           3188.367733          3.566257              3.276975
# 3              5.042754         23.811576              0.000000
# 4          10340.764250          3.938186              3.304958
# ...                 ...               ...                   ...
# 1083        5679.172743         23.828842              0.000000
# 1084        9522.891779          1.428610              6.046279
# 1085         932.825982         44.436516              0.000000
# 1086          55.217420         31.399462              0.000000
# 1087         741.135993          3.923547              4.671386
#
#       LiquidRate (STB/D)   WCUT (%)  GLR (SCF/STB)   FWHP (Psi)  \
# 0           11369.513090  76.481380     223.865461   305.330098
# 1           16328.920420  33.661507    1708.549521   435.628602
# 2           11641.083090  27.388927     306.350972   401.186641
# 3            2866.746297   0.175905    8306.133109  1952.873065
# 4           14747.207380  70.120152     267.046188   337.835564
# ...                  ...        ...            ...          ...
# 1083        13489.202300  42.101620    1766.512282   758.884956
# 1084        10614.095100  89.719300     134.595569   336.728929
# 1085         9260.670979  10.072985    4798.412176   978.262343
# 1086         6139.036971   0.899448    5114.721105  1492.401870
# 1087         1154.532340  64.193611    3398.386297   329.259620
#
#       Tubing ID (Inch)  FWHT (DegC)  WHP Fluctuation (%)  \
# 0                  5.5    66.785873             3.442966
# 1                  5.5    51.750969             3.302216
# 2                  5.5    60.219727            11.136396
# 3                  5.5    16.620888             1.352858
# 4                  5.5    66.567474            20.512606
# ...                ...          ...                  ...
# 1083               5.5    57.278549             0.838431
# 1084               5.5    65.796898            49.868549
# 1085               5.5    42.179749             0.805960
# 1086               5.5    33.089191             0.101950
# 1087               5.5    38.269619            16.803894
#
#       WHPFluctuation (Psi)  ChokeFluctuation (%)
# 0                 0.724804              0.004768
# 1                 0.991837              0.026222
# 2                 3.080416              0.720032
# 3                 1.821564              0.021458
# 4                 4.777981              0.021454
# ...                    ...                   ...
# 1083              0.438694              0.092983
# 1084             11.577782              0.026222
# 1085              0.543610              0.934620
# 1086              0.104904              0.224117
# 1087              3.814754              0.123978
#
# [1088 rows x 16 columns]

# %% [markdown]
# ## Data Pre-processing

# %%
trainDataset = preprocessing.getSluggingClass(trainDataset, WHPFluctuationTreshold=10)
trainDataset.head()

# %% [markdown]
# ## Modeling
